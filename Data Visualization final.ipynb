# %%
import pandas as pd

# %%
df = pd.read_csv("Topic_Survey_Assignment.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-10d0f6a95562> in <module>
# ----> 1 df = pd.read_csv("Topic_Survey_Assignment.csv")
#       2 df
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#               Very interested  Somewhat interested  Not interested  Unnamed: 3
# 0   Big Data (Spark / Hadoop)                 1332             729         127
# 1  Data Analysis / Statistics                 1688             444          60
# 2             Data Journalism                  429            1081         610
# 3          Data Visualization                 1340             734         102
# 4               Deep Learning                 1263             770         136

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
import matplotlib.pyplot as pplt
import matplotlib.patches as patches
import urllib
import json


df_data_1.plot(kind = "bar", figsize = (20,8), width = 0.8, color=('#5cb85c', '#5bc0de', '#d9534f'))
pplt.title("Percentage of Respondents' Interest in Data Science Areas", fontsize = 16)
pplt.legend(fontsize = 14)
pplt.xticks(fontsize = 14)
pplt.yticks([])
pplt.gca().spines['left'].set_visible(False)
pplt.gca().spines['right'].set_visible(False)
pplt.gca().spines['top'].set_visible(False)

for p in df_data_1.patches:
    width = p.get_width(),
    height = p.get_height(),
    x, y= p.get_xy(),
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c4c575368a00> in <module>
#      17 pplt.gca().spines['top'].set_visible(False)
#      18
# ---> 19 for p in df_data_1.patches:
#      20     width = p.get_width(),
#      21     height = p.get_height(),
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'patches'

# %%
# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/
streaming_body_1 = client_4e84888a19e34b3ca5a175c1471442a9.get_object(Bucket='datasciencecourse-donotdelete-pr-n7mg2yagn3f3sb', Key='Police_Department_Incidents_-_Previous_Year__2016_.zip')['Body']
# add missing __iter__ method so pandas accepts body as file-like object
if not hasattr(streaming_body_1, "__iter__"): streaming_body_1.__iter__ = types.MethodType( __iter__, streaming_body_1 )

# %%
body = client_4e84888a19e34b3ca5a175c1471442a9.get_object(Bucket='datasciencecourse-donotdelete-pr-n7mg2yagn3f3sb',Key='Police_Department_Incidents_-_Previous_Year__2016_.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
df_data_2.head(25)
# Out:
#     IncidntNum         Category  \
# 0    120058272      WEAPON LAWS
# 1    120058272      WEAPON LAWS
# 2    141059263         WARRANTS
# 3    160013662     NON-CRIMINAL
# 4    160002740     NON-CRIMINAL
# 5    160002869          ASSAULT
# 6    160003130   OTHER OFFENSES
# 7    160003259     NON-CRIMINAL
# 8    160003970         WARRANTS
# 9    160003641   MISSING PERSON
# 10   160086863    LARCENY/THEFT
# 11   160004053     NON-CRIMINAL
# 12   160073014   OTHER OFFENSES
# 13   140776777          ASSAULT
# 14   160004069         BURGLARY
# 15   160004150  STOLEN PROPERTY
# 16   160004241          ROBBERY
# 17   160004558          ASSAULT
# 18   160004655          ASSAULT
# 19   160004837    LARCENY/THEFT
# 20   160005421            FRAUD
# 21   160005750         WARRANTS
# 22   160005841    DRUG/NARCOTIC
# 23   160005841   OTHER OFFENSES
# 24   160006071          ASSAULT
#
#                                              Descript DayOfWeek  \
# ...
